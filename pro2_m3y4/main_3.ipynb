# %% [markdown]
# ## Идея продукта:
# приложение для генерации меню, соответствующего критериям ЗОЖ.
# ## Рынок:
# рынок общественного питания.
# ## Целевая аудитория:
# представители ЗОЖ.
# ## Пример исследовательского вопроса для изучения рынка:
# каким набором продуктов в McDonald's можно заменить один приём пищи, не превышая норму калорий?
# ## Гипотеза:
# на завтрак в McDonald's можно подобрать комбинацию продуктов, соответствующую нормам здорового питания.

# %%
import pandas as pd
df = pd.read_csv('./menu.csv')
# Out:
# /var/folders/hp/z71npf9j1011vv7k7dvvd6mr0000gn/T/ipykernel_58993/4213159529.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df
# Out:
#                Category                                               Item  \
# 0             Breakfast                                       Egg McMuffin
# 1             Breakfast                                  Egg White Delight
# 2             Breakfast                                   Sausage McMuffin
# 3             Breakfast                          Sausage McMuffin with Egg
# 4             Breakfast                   Sausage McMuffin with Egg Whites
# ..                  ...                                                ...
# 255  Smoothies & Shakes                 McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes                McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                 McFlurry with Oreo Cookies (Snack)
# 258  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Medium)
# 259  Smoothies & Shakes   McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# 0     4.8 oz (136 g)       300                120       13.0
# 1     4.8 oz (135 g)       250                 70        8.0
# 2     3.9 oz (111 g)       370                200       23.0
# 3     5.7 oz (161 g)       450                250       28.0
# 4     5.7 oz (161 g)       400                210       23.0
# ..               ...       ...                ...        ...
# 255  10.1 oz (285 g)       510                150       17.0
# 256  13.4 oz (381 g)       690                200       23.0
# 257   6.7 oz (190 g)       340                100       11.0
# 258  14.2 oz (403 g)       810                290       32.0
# 259   7.1 oz (202 g)       410                150       16.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 0                           20            5.0                             25
# 1                           12            3.0                             15
# 2                           35            8.0                             42
# 3                           43           10.0                             52
# 4                           35            8.0                             42
# ..                         ...            ...                            ...
# 255                         26            9.0                             44
# 256                         35           12.0                             58
# 257                         17            6.0                             29
# 258                         50           15.0                             76
# 259                         25            8.0                             38
#
#      Trans Fat  ...  Carbohydrates  Carbohydrates (% Daily Value)  \
# 0          0.0  ...             31                             10
# 1          0.0  ...             30                             10
# 2          0.0  ...             29                             10
# 3          0.0  ...             30                             10
# 4          0.0  ...             30                             10
# ..         ...  ...            ...                            ...
# 255        0.5  ...             80                             27
# 256        1.0  ...            106                             35
# 257        0.0  ...             53                             18
# 258        1.0  ...            114                             38
# 259        0.0  ...             57                             19
#
#      Dietary Fiber  Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 0                4                             17       3       17
# 1                4                             17       3       18
# 2                4                             17       2       14
# 3                4                             17       2       21
# 4                4                             17       2       21
# ..             ...                            ...     ...      ...
# 255              1                              4      64       12
# 256              1                              5      85       15
# 257              1                              2      43        8
# 258              2                              9     103       21
# 259              1                              5      51       10
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 0                           10                          0
# 1                            6                          0
# 2                            8                          0
# 3                           15                          0
# 4                            6                          0
# ..                         ...                        ...
# 255                         15                          0
# 256                         20                          0
# 257                         10                          0
# 258                         20                          0
# 259                         10                          0
#
#      Calcium (% Daily Value)  Iron (% Daily Value)
# 0                         25                    15
# 1                         25                     8
# 2                         25                    10
# 3                         30                    15
# 4                         25                    10
# ..                       ...                   ...
# 255                       40                     8
# 256                       50                    10
# 257                       25                     6
# 258                       60                     6
# 259                       30                     4
#
# [260 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
#  12  Sodium                         260 non-null    int64
#  13  Sodium (% Daily Value)         260 non-null    int64
#  14  Carbohydrates                  260 non-null    int64
#  15  Carbohydrates (% Daily Value)  260 non-null    int64
#  16  Dietary Fiber                  260 non-null    int64
#  17  Dietary Fiber (% Daily Value)  260 non-null    int64
#  18  Sugars                         260 non-null    int64
#  19  Protein                        260 non-null    int64
#  20  Vitamin A (% Daily Value)      260 non-null    int64
#  21  Vitamin C (% Daily Value)      260 non-null    int64
#  22  Calcium (% Daily Value)        260 non-null    int64
#  23  Iron (% Daily Value)           260 non-null    int64
# dtypes: float64(3), int64(18), object(3)
# memory usage: 48.9+ KB

# %%
df['Total calories'] = df['Calories'] + df['Calories from Fat']

# %%
filter_df = df[(df['Total calories'] <= 900)]
filter_df
# Out:
#                Category                                              Item  \
# 0             Breakfast                                      Egg McMuffin
# 1             Breakfast                                 Egg White Delight
# 2             Breakfast                                  Sausage McMuffin
# 3             Breakfast                         Sausage McMuffin with Egg
# 4             Breakfast                  Sausage McMuffin with Egg Whites
# ..                  ...                                               ...
# 254  Smoothies & Shakes               McFlurry with M&M’s Candies (Snack)
# 255  Smoothies & Shakes                McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes               McFlurry with Oreo Cookies (Medium)
# 257  Smoothies & Shakes                McFlurry with Oreo Cookies (Snack)
# 259  Smoothies & Shakes  McFlurry with Reese's Peanut Butter Cups (Snack)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# 0     4.8 oz (136 g)       300                120       13.0
# 1     4.8 oz (135 g)       250                 70        8.0
# 2     3.9 oz (111 g)       370                200       23.0
# 3     5.7 oz (161 g)       450                250       28.0
# 4     5.7 oz (161 g)       400                210       23.0
# ..               ...       ...                ...        ...
# 254   7.3 oz (207 g)       430                140       15.0
# 255  10.1 oz (285 g)       510                150       17.0
# 256  13.4 oz (381 g)       690                200       23.0
# 257   6.7 oz (190 g)       340                100       11.0
# 259   7.1 oz (202 g)       410                150       16.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 0                           20            5.0                             25
# 1                           12            3.0                             15
# 2                           35            8.0                             42
# 3                           43           10.0                             52
# 4                           35            8.0                             42
# ..                         ...            ...                            ...
# 254                         24           10.0                             48
# 255                         26            9.0                             44
# 256                         35           12.0                             58
# 257                         17            6.0                             29
# 259                         25            8.0                             38
#
#      Trans Fat  ...  Carbohydrates (% Daily Value)  Dietary Fiber  \
# 0          0.0  ...                             10              4
# 1          0.0  ...                             10              4
# 2          0.0  ...                             10              4
# 3          0.0  ...                             10              4
# 4          0.0  ...                             10              4
# ..         ...  ...                            ...            ...
# 254        0.0  ...                             21              1
# 255        0.5  ...                             27              1
# 256        1.0  ...                             35              1
# 257        0.0  ...                             18              1
# 259        0.0  ...                             19              1
#
#      Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 0                               17       3       17
# 1                               17       3       18
# 2                               17       2       14
# 3                               17       2       21
# 4                               17       2       21
# ..                             ...     ...      ...
# 254                              4      59        9
# 255                              4      64       12
# 256                              5      85       15
# 257                              2      43        8
# 259                              5      51       10
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 0                           10                          0
# 1                            6                          0
# 2                            8                          0
# 3                           15                          0
# 4                            6                          0
# ..                         ...                        ...
# 254                         10                          0
# 255                         15                          0
# 256                         20                          0
# 257                         10                          0
# 259                         10                          0
#
#      Calcium (% Daily Value)  Iron (% Daily Value)  Total calories
# 0                         25                    15             420
# 1                         25                     8             320
# 2                         25                    10             570
# 3                         30                    15             700
# 4                         25                    10             610
# ..                       ...                   ...             ...
# 254                       30                     4             570
# 255                       40                     8             660
# 256                       50                    10             890
# 257                       25                     6             440
# 259                       30                     4             560
#
# [234 rows x 25 columns]

# %% [markdown]
# ### 1 способ

# %%
filter_df['Category'].value_counts()
# Out:
# Category
# Coffee & Tea          92
# Breakfast             33
# Beverages             27
# Smoothies & Shakes    22
# Chicken & Fish        21
# Beef & Pork           13
# Snacks & Sides        13
# Desserts               7
# Salads                 6
# Name: count, dtype: int64

# %%
res1 = df[(df['Total calories'] <= 900) & (df['Total calories'] >= 600)]
res1
# Out:
#                Category                                           Item  \
# 3             Breakfast                      Sausage McMuffin with Egg
# 4             Breakfast               Sausage McMuffin with Egg Whites
# 5             Breakfast                           Steak & Egg McMuffin
# 6             Breakfast  Bacon, Egg & Cheese Biscuit (Regular Biscuit)
# 7             Breakfast    Bacon, Egg & Cheese Biscuit (Large Biscuit)
# ..                  ...                                            ...
# 248  Smoothies & Shakes                       Chocolate Shake (Medium)
# 250  Smoothies & Shakes                        Shamrock Shake (Medium)
# 252  Smoothies & Shakes            McFlurry with M&M’s Candies (Small)
# 255  Smoothies & Shakes             McFlurry with Oreo Cookies (Small)
# 256  Smoothies & Shakes            McFlurry with Oreo Cookies (Medium)
#
#         Serving Size  Calories  Calories from Fat  Total Fat  \
# 3     5.7 oz (161 g)       450                250       28.0
# 4     5.7 oz (161 g)       400                210       23.0
# 5     6.5 oz (185 g)       430                210       23.0
# 6     5.3 oz (150 g)       460                230       26.0
# 7     5.8 oz (164 g)       520                270       30.0
# ..               ...       ...                ...        ...
# 248     16 fl oz cup       700                180       20.0
# 250     16 fl oz cup       660                170       19.0
# 252  10.9 oz (310 g)       650                210       23.0
# 255  10.1 oz (285 g)       510                150       17.0
# 256  13.4 oz (381 g)       690                200       23.0
#
#      Total Fat (% Daily Value)  Saturated Fat  Saturated Fat (% Daily Value)  \
# 3                           43           10.0                             52
# 4                           35            8.0                             42
# 5                           36            9.0                             46
# 6                           40           13.0                             65
# 7                           47           14.0                             68
# ..                         ...            ...                            ...
# 248                         30           12.0                             62
# 250                         29           12.0                             61
# 252                         35           14.0                             72
# 255                         26            9.0                             44
# 256                         35           12.0                             58
#
#      Trans Fat  ...  Carbohydrates (% Daily Value)  Dietary Fiber  \
# 3          0.0  ...                             10              4
# 4          0.0  ...                             10              4
# 5          1.0  ...                             10              4
# 6          0.0  ...                             13              2
# 7          0.0  ...                             14              3
# ..         ...  ...                            ...            ...
# 248        1.0  ...                             38              2
# 250        1.0  ...                             36              0
# 252        0.5  ...                             32              1
# 255        0.5  ...                             27              1
# 256        1.0  ...                             35              1
#
#      Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 3                               17       2       21
# 4                               17       2       21
# 5                               18       3       26
# 6                                7       3       19
# 7                               12       4       19
# ..                             ...     ...      ...
# 248                              6      97       15
# 250                              0      93       14
# 252                              6      89       13
# 255                              4      64       12
# 256                              5      85       15
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 3                           15                          0
# 4                            6                          0
# 5                           15                          2
# 6                           10                          8
# 7                           15                          8
# ..                         ...                        ...
# 248                         25                          0
# 250                         25                          0
# 252                         15                          0
# 255                         15                          0
# 256                         20                          0
#
#      Calcium (% Daily Value)  Iron (% Daily Value)  Total calories
# 3                         30                    15             700
# 4                         25                    10             610
# 5                         30                    20             640
# 6                         15                    15             690
# 7                         20                    20             790
# ..                       ...                   ...             ...
# 248                       50                    10             880
# 250                       50                     0             830
# 252                       45                     8             860
# 255                       40                     8             660
# 256                       50                    10             890
#
# [68 rows x 25 columns]

# %%
res = pd.merge(filter_df['Item'], filter_df['Item'], how='cross') # !
res
# Out:
#                                                  Item_x  \
# 0                                          Egg McMuffin
# 1                                          Egg McMuffin
# 2                                          Egg McMuffin
# 3                                          Egg McMuffin
# 4                                          Egg McMuffin
# ...                                                 ...
# 54751  McFlurry with Reese's Peanut Butter Cups (Snack)
# 54752  McFlurry with Reese's Peanut Butter Cups (Snack)
# 54753  McFlurry with Reese's Peanut Butter Cups (Snack)
# 54754  McFlurry with Reese's Peanut Butter Cups (Snack)
# 54755  McFlurry with Reese's Peanut Butter Cups (Snack)
#
#                                                  Item_y
# 0                                          Egg McMuffin
# 1                                     Egg White Delight
# 2                                      Sausage McMuffin
# 3                             Sausage McMuffin with Egg
# 4                      Sausage McMuffin with Egg Whites
# ...                                                 ...
# 54751               McFlurry with M&M’s Candies (Snack)
# 54752                McFlurry with Oreo Cookies (Small)
# 54753               McFlurry with Oreo Cookies (Medium)
# 54754                McFlurry with Oreo Cookies (Snack)
# 54755  McFlurry with Reese's Peanut Butter Cups (Snack)
#
# [54756 rows x 2 columns]

# %%
res_cal = pd.merge(filter_df['Total calories'], filter_df['Total calories'], how='cross')
res_cal
# Out:
#        Total calories_x  Total calories_y
# 0                   420               420
# 1                   420               320
# 2                   420               570
# 3                   420               700
# 4                   420               610
# ...                 ...               ...
# 54751               560               570
# 54752               560               660
# 54753               560               890
# 54754               560               440
# 54755               560               560
#
# [54756 rows x 2 columns]

# %%
res_with_cal = pd.merge(res, res_cal, left_index=True, right_index=True)
res_with_cal
# Out:
#                                                  Item_x  \
# 0                                          Egg McMuffin
# 1                                          Egg McMuffin
# 2                                          Egg McMuffin
# 3                                          Egg McMuffin
# 4                                          Egg McMuffin
# ...                                                 ...
# 54751  McFlurry with Reese's Peanut Butter Cups (Snack)
# 54752  McFlurry with Reese's Peanut Butter Cups (Snack)
# 54753  McFlurry with Reese's Peanut Butter Cups (Snack)
# 54754  McFlurry with Reese's Peanut Butter Cups (Snack)
# 54755  McFlurry with Reese's Peanut Butter Cups (Snack)
#
#                                                  Item_y  Total calories_x  \
# 0                                          Egg McMuffin               420
# 1                                     Egg White Delight               420
# 2                                      Sausage McMuffin               420
# 3                             Sausage McMuffin with Egg               420
# 4                      Sausage McMuffin with Egg Whites               420
# ...                                                 ...               ...
# 54751               McFlurry with M&M’s Candies (Snack)               560
# 54752                McFlurry with Oreo Cookies (Small)               560
# 54753               McFlurry with Oreo Cookies (Medium)               560
# 54754                McFlurry with Oreo Cookies (Snack)               560
# 54755  McFlurry with Reese's Peanut Butter Cups (Snack)               560
#
#        Total calories_y
# 0                   420
# 1                   320
# 2                   570
# 3                   700
# 4                   610
# ...                 ...
# 54751               570
# 54752               660
# 54753               890
# 54754               440
# 54755               560
#
# [54756 rows x 4 columns]

# %%
res_with_cal = res_with_cal.assign(Sum=res_with_cal['Total calories_x'] + res_with_cal['Total calories_y'])
res_with_cal
# Out:
#                                                  Item_x  \
# 0                                          Egg McMuffin
# 1                                          Egg McMuffin
# 2                                          Egg McMuffin
# 3                                          Egg McMuffin
# 4                                          Egg McMuffin
# ...                                                 ...
# 54751  McFlurry with Reese's Peanut Butter Cups (Snack)
# 54752  McFlurry with Reese's Peanut Butter Cups (Snack)
# 54753  McFlurry with Reese's Peanut Butter Cups (Snack)
# 54754  McFlurry with Reese's Peanut Butter Cups (Snack)
# 54755  McFlurry with Reese's Peanut Butter Cups (Snack)
#
#                                                  Item_y  Total calories_x  \
# 0                                          Egg McMuffin               420
# 1                                     Egg White Delight               420
# 2                                      Sausage McMuffin               420
# 3                             Sausage McMuffin with Egg               420
# 4                      Sausage McMuffin with Egg Whites               420
# ...                                                 ...               ...
# 54751               McFlurry with M&M’s Candies (Snack)               560
# 54752                McFlurry with Oreo Cookies (Small)               560
# 54753               McFlurry with Oreo Cookies (Medium)               560
# 54754                McFlurry with Oreo Cookies (Snack)               560
# 54755  McFlurry with Reese's Peanut Butter Cups (Snack)               560
#
#        Total calories_y   Sum
# 0                   420   840
# 1                   320   740
# 2                   570   990
# 3                   700  1120
# 4                   610  1030
# ...                 ...   ...
# 54751               570  1130
# 54752               660  1220
# 54753               890  1450
# 54754               440  1000
# 54755               560  1120
#
# [54756 rows x 5 columns]

# %%
res_with_cal.drop(columns=['Total calories_x', 'Total calories_y'], inplace=True)
res_with_cal
# Out:
#                                                  Item_x  \
# 0                                          Egg McMuffin
# 1                                          Egg McMuffin
# 2                                          Egg McMuffin
# 3                                          Egg McMuffin
# 4                                          Egg McMuffin
# ...                                                 ...
# 54751  McFlurry with Reese's Peanut Butter Cups (Snack)
# 54752  McFlurry with Reese's Peanut Butter Cups (Snack)
# 54753  McFlurry with Reese's Peanut Butter Cups (Snack)
# 54754  McFlurry with Reese's Peanut Butter Cups (Snack)
# 54755  McFlurry with Reese's Peanut Butter Cups (Snack)
#
#                                                  Item_y   Sum
# 0                                          Egg McMuffin   840
# 1                                     Egg White Delight   740
# 2                                      Sausage McMuffin   990
# 3                             Sausage McMuffin with Egg  1120
# 4                      Sausage McMuffin with Egg Whites  1030
# ...                                                 ...   ...
# 54751               McFlurry with M&M’s Candies (Snack)  1130
# 54752                McFlurry with Oreo Cookies (Small)  1220
# 54753               McFlurry with Oreo Cookies (Medium)  1450
# 54754                McFlurry with Oreo Cookies (Snack)  1000
# 54755  McFlurry with Reese's Peanut Butter Cups (Snack)  1120
#
# [54756 rows x 3 columns]

# %%
res2 = res_with_cal[(res_with_cal['Sum'] <= 900) & (res_with_cal['Sum'] >= 600)]
res2
# Out:
#                                                  Item_x  \
# 0                                          Egg McMuffin
# 1                                          Egg McMuffin
# 26                                         Egg McMuffin
# 28                                         Egg McMuffin
# 29                                         Egg McMuffin
# ...                                                 ...
# 54737  McFlurry with Reese's Peanut Butter Cups (Snack)
# 54738  McFlurry with Reese's Peanut Butter Cups (Snack)
# 54739  McFlurry with Reese's Peanut Butter Cups (Snack)
# 54740  McFlurry with Reese's Peanut Butter Cups (Snack)
# 54741  McFlurry with Reese's Peanut Butter Cups (Snack)
#
#                                     Item_y  Sum
# 0                             Egg McMuffin  840
# 1                        Egg White Delight  740
# 26                                Hotcakes  850
# 28                         Sausage Burrito  870
# 29                              Hash Brown  650
# ...                                    ...  ...
# 54737   Strawberry Banana Smoothie (Small)  775
# 54738  Strawberry Banana Smoothie (Medium)  815
# 54739   Strawberry Banana Smoothie (Large)  900
# 54740     Mango Pineapple Smoothie (Small)  775
# 54741    Mango Pineapple Smoothie (Medium)  830
#
# [17165 rows x 3 columns]

# %% [markdown]
# ### 2 способ

# %%
products = dict(zip(filter_df['Item'], filter_df['Total calories']))
products
# Out:
# {'Egg McMuffin': 420,
#  'Egg White Delight': 320,
#  'Sausage McMuffin': 570,
#  'Sausage McMuffin with Egg': 700,
#  'Sausage McMuffin with Egg Whites': 610,
#  'Steak & Egg McMuffin': 640,
#  'Bacon, Egg & Cheese Biscuit (Regular Biscuit)': 690,
#  'Bacon, Egg & Cheese Biscuit (Large Biscuit)': 790,
#  'Bacon, Egg & Cheese Biscuit with Egg Whites (Regular Biscuit)': 590,
#  'Bacon, Egg & Cheese Biscuit with Egg Whites (Large Biscuit)': 690,
#  'Sausage Biscuit (Regular Biscuit)': 670,
#  'Sausage Biscuit (Large Biscuit)': 760,
#  'Sausage Biscuit with Egg (Regular Biscuit)': 800,
#  'Sausage Biscuit with Egg (Large Biscuit)': 900,
#  'Sausage Biscuit with Egg Whites (Regular Biscuit)': 710,
#  'Sausage Biscuit with Egg Whites (Large Biscuit)': 800,
#  'Southern Style Chicken Biscuit (Regular Biscuit)': 590,
#  'Southern Style Chicken Biscuit (Large Biscuit)': 690,
#  'Steak & Egg Biscuit (Regular Biscuit)': 830,
#  'Bacon, Egg & Cheese McGriddles': 650,
#  'Bacon, Egg & Cheese McGriddles with Egg Whites': 540,
#  'Sausage McGriddles': 620,
#  'Sausage, Egg & Cheese McGriddles': 830,
#  'Sausage, Egg & Cheese McGriddles with Egg Whites': 730,
#  'Bacon, Egg & Cheese Bagel': 900,
#  'Bacon, Egg & Cheese Bagel with Egg Whites': 800,
#  'Hotcakes': 430,
#  'Hotcakes and Sausage': 730,
#  'Sausage Burrito': 450,
#  'Hash Brown': 230,
#  'Cinnamon Melts': 630,
#  'Fruit & Maple Oatmeal': 325,
#  'Fruit & Maple Oatmeal without Brown Sugar': 300,
#  'Big Mac': 770,
#  'Quarter Pounder with Cheese': 760,
#  'Quarter Pounder with Bacon & Cheese': 860,
#  'Quarter Pounder with Bacon Habanero Ranch': 890,
#  'Quarter Pounder Deluxe': 790,
#  'Hamburger': 310,
#  'Cheeseburger': 390,
#  'Double Cheeseburger': 620,
#  'McDouble': 530,
#  'Bacon McDouble': 640,
#  'Daily Double': 630,
#  'Jalapeño Double': 640,
#  'McRib': 740,
#  'Premium Crispy Chicken Classic Sandwich': 710,
#  'Premium Grilled Chicken Classic Sandwich': 430,
#  'Premium Grilled Chicken Club Sandwich': 690,
#  'Premium Crispy Chicken Ranch BLT Sandwich': 860,
#  'Premium Grilled Chicken Ranch BLT Sandwich': 580,
#  'Bacon Clubhouse Grilled Chicken Sandwich': 820,
#  'Southern Style Crispy Chicken Sandwich': 600,
#  'McChicken': 500,
#  'Bacon Cheddar McChicken': 700,
#  'Bacon Buffalo Ranch McChicken': 620,
#  'Buffalo Ranch McChicken': 510,
#  'Premium McWrap Chicken & Bacon (Grilled Chicken)': 650,
#  'Premium McWrap Chicken & Ranch (Crispy Chicken)': 890,
#  'Premium McWrap Chicken & Ranch (Grilled Chicken)': 610,
#  'Premium McWrap Southwest Chicken (Grilled Chicken)': 700,
#  'Premium McWrap Chicken Sweet Chili (Crispy Chicken)': 740,
#  'Premium McWrap Chicken Sweet Chili (Grilled Chicken)': 470,
#  'Chicken McNuggets (4 piece)': 300,
#  'Chicken McNuggets (6 piece)': 440,
#  'Chicken McNuggets (10 piece)': 740,
#  'Filet-O-Fish': 560,
#  'Premium Bacon Ranch Salad (without Chicken)': 210,
#  'Premium Bacon Ranch Salad with Crispy Chicken': 570,
#  'Premium Bacon Ranch Salad with Grilled Chicken': 300,
#  'Premium Southwest Salad (without Chicken)': 180,
#  'Premium Southwest Salad with Crispy Chicken': 640,
#  'Premium Southwest Salad with Grilled Chicken': 370,
#  'Chipotle BBQ Snack Wrap (Crispy Chicken)': 470,
#  'Chipotle BBQ Snack Wrap (Grilled Chicken)': 330,
#  'Honey Mustard Snack Wrap (Crispy Chicken)': 460,
#  'Honey Mustard Snack Wrap (Grilled Chicken)': 320,
#  'Ranch Snack Wrap (Crispy Chicken)': 540,
#  'Ranch Snack Wrap (Grilled Chicken)': 400,
#  'Small French Fries': 330,
#  'Medium French Fries': 480,
#  'Large French Fries': 730,
#  'Kids French Fries': 160,
#  'Side Salad': 20,
#  'Apple Slices': 15,
#  "Fruit 'n Yogurt Parfait": 170,
#  'Baked Apple Pie': 360,
#  'Chocolate Chip Cookie': 230,
#  'Oatmeal Raisin Cookie': 200,
#  'Kids Ice Cream Cone': 55,
#  'Hot Fudge Sundae': 410,
#  'Hot Caramel Sundae': 410,
#  'Strawberry Sundae': 340,
#  'Coca-Cola Classic (Small)': 140,
#  'Coca-Cola Classic (Medium)': 200,
#  'Coca-Cola Classic (Large)': 280,
#  'Coca-Cola Classic (Child)': 100,
#  'Diet Coke (Small)': 0,
#  'Diet Coke (Medium)': 0,
#  'Diet Coke (Large)': 0,
#  'Diet Coke (Child)': 0,
#  'Dr Pepper (Small)': 140,
#  'Dr Pepper (Medium)': 190,
#  'Dr Pepper (Large)': 270,
#  'Dr Pepper (Child)': 100,
#  'Diet Dr Pepper (Small)': 0,
#  'Diet Dr Pepper (Medium)': 0,
#  'Diet Dr Pepper (Large)': 0,
#  'Diet Dr Pepper (Child)': 0,
#  'Sprite (Small)': 140,
#  'Sprite (Medium)': 200,
#  'Sprite (Large)': 280,
#  'Sprite (Child)': 100,
#  '1% Low Fat Milk Jug': 120,
#  'Fat Free Chocolate Milk Jug': 130,
#  'Minute Maid 100% Apple Juice Box': 80,
#  'Minute Maid Orange Juice (Small)': 150,
#  'Minute Maid Orange Juice (Medium)': 190,
#  'Minute Maid Orange Juice (Large)': 280,
#  'Dasani Water Bottle': 0,
#  'Iced Tea (Small)': 0,
#  'Iced Tea (Medium)': 0,
#  'Iced Tea (Large)': 0,
#  'Iced Tea (Child)': 0,
#  'Sweet Tea (Small)': 150,
#  'Sweet Tea (Medium)': 180,
#  'Sweet Tea (Large)': 220,
#  'Sweet Tea (Child)': 110,
#  'Coffee (Small)': 0,
#  'Coffee (Medium)': 0,
#  'Coffee (Large)': 0,
#  'Latte (Small)': 250,
#  'Latte (Medium)': 300,
#  'Latte (Large)': 400,
#  'Caramel Latte (Small)': 350,
#  'Caramel Latte (Medium)': 430,
#  'Caramel Latte (Large)': 550,
#  'Hazelnut Latte (Small)': 350,
#  'Hazelnut Latte (Medium)': 420,
#  'Hazelnut Latte (Large)': 550,
#  'French Vanilla Latte (Small)': 340,
#  'French Vanilla Latte (Medium)': 420,
#  'French Vanilla Latte (Large)': 540,
#  'Latte with Sugar Free French Vanilla Syrup (Small)': 290,
#  'Latte with Sugar Free French Vanilla Syrup (Medium)': 350,
#  'Latte with Sugar Free French Vanilla Syrup (Large)': 450,
#  'Nonfat Latte (Small)': 100,
#  'Nonfat Latte (Medium)': 130,
#  'Nonfat Latte (Large)': 170,
#  'Nonfat Caramel Latte (Small)': 200,
#  'Nonfat Caramel Latte (Medium)': 250,
#  'Nonfat Caramel Latte (Large)': 310,
#  'Nonfat Hazelnut Latte (Small)': 200,
#  'Nonfat Hazelnut Latte (Medium)': 250,
#  'Nonfat Hazelnut Latte (Large)': 310,
#  'Nonfat French Vanilla Latte (Small)': 190,
#  'Nonfat French Vanilla Latte (Medium)': 240,
#  'Nonfat French Vanilla Latte (Large)': 300,
#  'Nonfat Latte with Sugar Free French Vanilla Syrup (Small)': 140,
#  'Nonfat Latte with Sugar Free French Vanilla Syrup (Medium)': 170,
#  'Nonfat Latte with Sugar Free French Vanilla Syrup (Large)': 220,
#  'Mocha (Small)': 440,
#  'Mocha (Medium)': 530,
#  'Mocha (Large)': 650,
#  'Mocha with Nonfat Milk (Small)': 300,
#  'Mocha with Nonfat Milk (Medium)': 360,
#  'Mocha with Nonfat Milk (Large)': 425,
#  'Caramel Mocha (Small)': 420,
#  'Caramel Mocha (Medium)': 510,
#  'Caramel Mocha (Large)': 630,
#  'Nonfat Caramel Mocha (Small)': 280,
#  'Nonfat Caramel Mocha (Medium)': 340,
#  'Nonfat Caramel Mocha (Large)': 405,
#  'Hot Chocolate (Small)': 480,
#  'Hot Chocolate (Medium)': 580,
#  'Hot Chocolate (Large)': 720,
#  'Hot Chocolate with Nonfat Milk (Small)': 310,
#  'Hot Chocolate with Nonfat Milk (Medium)': 370,
#  'Hot Chocolate with Nonfat Milk (Large)': 435,
#  'Regular Iced Coffee (Small)': 180,
#  'Regular Iced Coffee (Medium)': 250,
#  'Regular Iced Coffee (Large)': 350,
#  'Caramel Iced Coffee (Small)': 170,
#  'Caramel Iced Coffee (Medium)': 240,
#  'Caramel Iced Coffee (Large)': 340,
#  'Hazelnut Iced Coffee (Small)': 170,
#  'Hazelnut Iced Coffee (Medium)': 240,
#  'Hazelnut Iced Coffee (Large)': 330,
#  'French Vanilla Iced Coffee (Small)': 160,
#  'French Vanilla Iced Coffee (Medium)': 230,
#  'French Vanilla Iced Coffee (Large)': 320,
#  'Iced Coffee with Sugar Free French Vanilla Syrup (Small)': 120,
#  'Iced Coffee with Sugar Free French Vanilla Syrup (Medium)': 180,
#  'Iced Coffee with Sugar Free French Vanilla Syrup (Large)': 240,
#  'Iced Mocha (Small)': 390,
#  'Iced Mocha (Medium)': 460,
#  'Iced Mocha (Large)': 630,
#  'Iced Mocha with Nonfat Milk (Small)': 285,
#  'Iced Mocha with Nonfat Milk (Medium)': 335,
#  'Iced Mocha with Nonfat Milk (Large)': 440,
#  'Iced Caramel Mocha (Small)': 380,
#  'Iced Caramel Mocha (Medium)': 450,
#  'Iced Caramel Mocha (Large)': 610,
#  'Iced Nonfat Caramel Mocha (Small)': 275,
#  'Iced Nonfat Caramel Mocha (Medium)': 315,
#  'Iced Nonfat Caramel Mocha (Large)': 420,
#  'Frappé Mocha (Small)': 610,
#  'Frappé Mocha (Medium)': 750,
#  'Frappé Caramel (Small)': 620,
#  'Frappé Caramel (Medium)': 750,
#  'Frappé Chocolate Chip (Small)': 730,
#  'Frappé Chocolate Chip (Medium)': 870,
#  'Blueberry Pomegranate Smoothie (Small)': 225,
#  'Blueberry Pomegranate Smoothie (Medium)': 265,
#  'Blueberry Pomegranate Smoothie (Large)': 350,
#  'Strawberry Banana Smoothie (Small)': 215,
#  'Strawberry Banana Smoothie (Medium)': 255,
#  'Strawberry Banana Smoothie (Large)': 340,
#  'Mango Pineapple Smoothie (Small)': 215,
#  'Mango Pineapple Smoothie (Medium)': 270,
#  'Mango Pineapple Smoothie (Large)': 350,
#  'Vanilla Shake (Small)': 670,
#  'Vanilla Shake (Medium)': 830,
#  'Strawberry Shake (Small)': 700,
#  'Strawberry Shake (Medium)': 870,
#  'Chocolate Shake (Small)': 710,
#  'Chocolate Shake (Medium)': 880,
#  'Shamrock Shake (Medium)': 830,
#  'McFlurry with M&M’s Candies (Small)': 860,
#  'McFlurry with M&M’s Candies (Snack)': 570,
#  'McFlurry with Oreo Cookies (Small)': 660,
#  'McFlurry with Oreo Cookies (Medium)': 890,
#  'McFlurry with Oreo Cookies (Snack)': 440,
#  "McFlurry with Reese's Peanut Butter Cups (Snack)": 560}

# %%
# создаем генератор
"""
https://skillbox.ru/media/code/generatory_python_chto_eto_takoe_i_zachem_oni_nuzhny/

https://habr.com/ru/articles/560300/
"""

def new_product():
    for i in products:
        yield i

np = new_product()
print(next(np))
print(next(np))
# Out:
# Egg McMuffin
# Egg White Delight

# %% [markdown]
# ``` Python
# from itertools import combinations
# # https://docs.python.org/3/library/itertools.html
#
# lst = range(256) # ? вариантов
# i = 0
# for r in range(1, len(lst) + 1):
#     for comb in combinations(lst, r):
#         # print(comb)
#         i += 1
#
# print(i)
# ```

# %% [markdown]
# ``` Python
# prod = list(products.keys())
#
# res = []
#
# for i in range(1, len(prod) + 1):
#     for comb in combinations(prod, i):
#         total = 0
#         if i != 1:
#             for item in comb:
#                 total += products[item]
#             if 600 <= total <= 900:
#                 res.append(comb)
#         else:
#             if 600 <= products[comb[0]] <= 900:
#                 res.append(comb)
#
# res
# # код выполняется больше 12 часов
# ```

# %% [markdown]
# ## Выборка все еще слишком большая, возможно стоит присмотреться к доп. фильтрации по бжу или по количеству товаров
